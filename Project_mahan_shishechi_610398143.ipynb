# %% [markdown]
# # Loading Images

# %%
import os
import sys
from pycocotools.coco import COCO
import urllib
import zipfile
market1501_url = 'https://www.muratkoklu.com/datasets/Grapevine_Leaves_Image_Dataset.zip'
urllib.request.urlretrieve(market1501_url , filename = 'Grapevine_Leaves_Image_Dataset.zip' )
with zipfile.ZipFile('Grapevine_Leaves_Image_Dataset.zip' , 'r') as zip_ref:
    zip_ref.extractall()

# %%
from google.colab.patches import cv2_imshow
from skimage import io
img_path = "/content/Grapevine_Leaves_Image_Dataset/Ak/Ak (1).png"
image = io.imread(img_path)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGBA size=511x511 at 0x7F618A15B250>

# %%
import pathlib
data_dir = '/content/Grapevine_Leaves_Image_Dataset'
data_dir = pathlib.Path(data_dir)
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 500

# %%
Ak = list(data_dir.glob('Ak/*'))
Ala_Idris = list(data_dir.glob('Ala_Idris/*'))
Buzgulu = list(data_dir.glob('Buzgulu/*'))
Dimnit = list(data_dir.glob('Dimnit/*'))
Nazli = list(data_dir.glob('Nazli/*'))

#PIL.Image.open(str(Ak[1]))
#PIL.Image.open(str(Ala_Idris[1]))
#PIL.Image.open(str(Buzgulu[1]))
#PIL.Image.open(str(Dimnit[1]))
PIL.Image.open(str(Nazli[1]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=511x511 at 0x7F6187F5D290>
